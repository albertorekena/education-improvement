# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from imblearn.over_sampling import SMOTE

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',1000)

# %%
df_por = pd.read_pickle('df_por-modelling-range_G3_5-repaired_G3_0_values.pkl')

df_por.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  \
# 0       1    1   18        1        1        0     4     4           2
# 1       1    1   17        1        1        1     1     1           1
# 2       1    1   15        1        0        1     1     1           1
# 3       1    1   15        1        1        1     4     2           1
# 4       1    1   16        1        1        1     3     3           1
#
#    studytime  schoolsup  famsup  paid  activities  nursery  higher  internet  \
# 0          2          1       0     0           0        1       1         0
# 1          2          0       1     0           0        0       1         1
# 2          2          1       0     0           0        1       1         1
# 3          3          0       1     0           1        1       1         1
# 4          2          0       1     0           0        1       1         0
#
#    romantic  famrel  freetime  goout  Dalc  Walc  health  absences  G3  \
# ...

# %%
df_por.shape
# Out:
# (649, 43)

# %%
X = np.array(df_por.drop('G3',axis = 1))
y = np.array(df_por['G3'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,stratify = y,random_state = 42)

# %%
sm = SMOTE(k_neighbors = 3,random_state = 42)

# %%
X_train,y_train = sm.fit_resample(X_train,y_train)

# %%
X_train.shape
# Out:
# (1235, 42)

# %%
model = RandomForestClassifier(n_estimators = 500,max_depth = 30,min_samples_split = 2,min_samples_leaf = 1)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=30, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = model.predict(X_test)

# %%
feature_importances = model.feature_importances_
feature_importances_indices = np.argsort(feature_importances)

plt.figure(figsize = (10,16))
plt.barh(range(len(feature_importances_indices)),feature_importances[feature_importances_indices],align = 'center')
plt.yticks(range(len(feature_importances_indices)),[list(df_por.columns)[i] for i in feature_importances_indices])
plt.gca().xaxis.grid(True)
plt.title('Feature Importances')
plt.xlabel('Relative Importance');
